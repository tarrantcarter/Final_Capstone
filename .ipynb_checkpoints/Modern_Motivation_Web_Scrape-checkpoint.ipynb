# %%
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git --quiet

# %%
import pandas as pd
import os
import time

# %%
usernames = ['LewisHowes','StephenRCovey','briantracy','WayneDyerQuotes','TonyRobbins101','RobinSharma',
             'Jim_Rohn_Quotes','JimRohnBot','Jimrohnwords','sharmaisms','OneWiseMan__','OprahQuote',
             'OprahsQuotes','bobproctorLIVE','QuotesGoggins','GaryVQuotes','GaryVee_Quotes','simonsinek',
             'dailystoic','BrendonBurchard','TomBilyeu','ReelLifeWisdom','StoicQuoteBot','TimelessStoic',
             'lawsofaurelius','QuoteAurelius','QuoteBuffett','jimkwik','ShawnModel','marieforleo',
             'DaveRamsey','thesuccesstalk','SuccessQotes','InsipereLifeMe','MotivateMsgs','MotivationalUi',
             'InspiredUs','Life__Quotes']

# %%
# Start scraping runtime
start_time = time.time()

# Setting variables to be used in format string command below
tweet_count = 300000

tweets = pd.DataFrame()

for username in usernames:
    # Using OS library to call CLI commands in Python
    os.system("snscrape --jsonl --max-results {} twitter-search 'from:{}'> user-tweets.json".format(tweet_count, username))
    # Reads the json generated from the CLI command above and creates a pandas dataframe
    user_tweets = pd.read_json('user-tweets.json', lines=True)
    # Append user tweets to dataframe with all tweets
    tweets = tweets.append(user_tweets)

# Print scraping runtime
print(time.strftime(f'%H hours, %M minutes, %S seconds', time.gmtime(time.time() - start_time)))
# Out:
# 00 hours, 01 minutes, 10 seconds

# %%
# Displays first 5 entries from dataframe
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/LewisHowes/status/13506630...
# 0  https://twitter.com/StephenRCovey/status/13507...
# 0  https://twitter.com/BrianTracy/status/13508513...
# 0  https://twitter.com/WayneDyerQuotes/status/583...
# 0  https://twitter.com/TonyRobbins101/status/1009...
#
#                        date  \
# 0 2021-01-17 04:35:28+00:00
# 0 2021-01-17 13:00:41+00:00
# 0 2021-01-17 17:04:03+00:00
# 0 2015-04-02 18:30:16+00:00
# 0 2018-06-19 10:38:08+00:00
#
#                                              content  \
# 0  @emilsterndorff @awilkinson @supercast @thecap...
# 0  "Our greatest glory is not in never falling, b...
# 0  The time is now to improve your public speakin...
# 0  ☯ "Focus on What you Have to Give." ~Wayne Dye...
# 0  The way we communicate with others and with ou...
#
#                                      renderedContent                   id  \
# 0  @emilsterndorff @awilkinson @supercast @thecap...  1350663002639400960
# 0  "Our greatest glory is not in never falling, b...  1350790144991911936
# 0  The time is now to improve your public speakin...  1350851389111623680
# 0  ☯ "Focus on What you Have to Give." ~Wayne Dye...   583697975077134336
# 0  The way we communicate with others and with ou...  1009022513651871745
#
#                                                 user                 outlinks  \
# 0  {'username': 'LewisHowes', 'displayname': 'Lew...                       []
# 0  {'username': 'StephenRCovey', 'displayname': '...                       []
# 0  {'username': 'BrianTracy', 'displayname': 'Bri...  [http://bit.ly/3q8b8eT]
# 0  {'username': 'WayneDyerQuotes', 'displayname':...                       []
# 0  {'username': 'TonyRobbins101', 'displayname': ...                       []
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0                         []           0             0  ...           0
# 0                         []           0            47  ...           2
# 0  [https://t.co/b3JNnkOkBX]           0             2  ...           0
# 0                         []          14           267  ...           8
# 0                         []           0            10  ...           0
#
#         conversationId  lang  \
# 0  1350132120094556160    en
# 0  1350790144991911936    en
# 0  1350851389111623680    en
# 0   583697975077134336    en
# 0  1009022513651871745    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 0  <a href="https://www.hootsuite.com" rel="nofol...
# 0  <a href="https://app.agorapulse.com" rel="nofo...
# 0  <a href="https://www.socialoomph.com" rel="nof...
# 0  <a href="https://ifttt.com" rel="nofollow">IFT...
#
#                             sourceUrl         sourceLabel  \
# 0  http://twitter.com/download/iphone  Twitter for iPhone
# 0           https://www.hootsuite.com      Hootsuite Inc.
# 0          https://app.agorapulse.com  AgoraPulse Manager
# 0         https://www.socialoomph.com         SocialOomph
# 0                   https://ifttt.com               IFTTT
#
#                                                media retweetedTweet  \
# 0                                                NaN            NaN
# 0  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 0                                                NaN            NaN
# 0                                                NaN            NaN
# 0                                                NaN            NaN
#
#    quotedTweet                                     mentionedUsers
# 0          NaN  [{'username': 'emilsterndorff', 'displayname':...
# 0          NaN                                                NaN
# 0          NaN                                                NaN
# 0          NaN                                                NaN
# 0          NaN                                                NaN
#
# [5 rows x 21 columns]

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 0
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              38 non-null     object
#  1   date             38 non-null     datetime64[ns, UTC]
#  2   content          38 non-null     object
#  3   renderedContent  38 non-null     object
#  4   id               38 non-null     int64
#  5   user             38 non-null     object
#  6   outlinks         38 non-null     object
#  7   tcooutlinks      38 non-null     object
#  8   replyCount       38 non-null     int64
#  9   retweetCount     38 non-null     int64
#  10  likeCount        38 non-null     int64
#  11  quoteCount       38 non-null     int64
#  12  conversationId   38 non-null     int64
#  13  lang             38 non-null     object
#  14  source           38 non-null     object
#  15  sourceUrl        38 non-null     object
#  16  sourceLabel      38 non-null     object
#  17  media            4 non-null      object
#  18  retweetedTweet   0 non-null      float64
#  19  quotedTweet      0 non-null      float64
#  20  mentionedUsers   3 non-null      object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(6), object(12)
# memory usage: 6.5+ KB

# %%
# Export dataframe into a CSV
tweets_df1.to_csv('motivational_tweets.csv', sep=',', index=False)
